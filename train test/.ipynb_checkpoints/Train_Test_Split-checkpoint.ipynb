# %% [markdown]
# ![tts1.PNG](attachment:tts1.PNG)

# %% [markdown]
# ### Our Data is :
# ![tts2.PNG](attachment:tts2.PNG)

# %%
import pandas as pd

# %%
df = pd.read_csv(r"car_price.csv")
df.shape
# Out:
# (13, 3)

# %%
df.head(4)
# Out:
#    mileage  sell_price  age
# 0    69000       18000    6
# 1    35000       34000    3
# 2    57000       26100    5
# 3    22500       40000    2

# %%
df.corr()
# Out:
#              mileage  sell_price       age
# mileage     1.000000   -0.927116  0.993452
# sell_price -0.927116    1.000000 -0.921741
# age         0.993452   -0.921741  1.000000

# %% [markdown]
# ###  Visulization :

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.age,df.sell_price)
plt.xlabel('Age')
plt.ylabel('Sell_Price')
# Out:
# Text(0, 0.5, 'Sell_Price')

# %%
plt.scatter(df.mileage,df.sell_price)
plt.xlabel('Mileage')
plt.ylabel('Sell_Price')
# Out:
# Text(0, 0.5, 'Sell_Price')

# %%
plt.scatter(df.age,df.mileage)
plt.xlabel('Age')
plt.ylabel('KM')
# Out:
# Text(0, 0.5, 'KM')

# %%
df.head(3)
# Out:
#     mileage  sell_price  age
# 0     69000       18000    6
# 1     35000       34000    3
# 2     57000       26100    5
# 3     22500       40000    2
# 4     46000       31500    4
# 5     59000       29400    5
# 6     52000       32000    5
# 7     72000       19300    6
# 8     91000       12000    8
# 9     67000       22000    6
# 10    83000       20000    7
# 11    79000       21000    7
# 12    59000       33000    5

# %%
x = df.drop('sell_price',axis = 1)
y = df.sell_price
print("This is x :\n",x)
print()
print("This is y :\n",y)
# Out:
# This is x :
#      mileage  age
# 0     69000    6
# 1     35000    3
# 2     57000    5
# 3     22500    2
# 4     46000    4
# 5     59000    5
# 6     52000    5
# 7     72000    6
# 8     91000    8
# 9     67000    6
# 10    83000    7
# 11    79000    7
# 12    59000    5
#
# This is y :
#  0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: sell_price, dtype: int64

# %%
# OR
x = df[['mileage','age']]
y = df['sell_price']
print("This is x :\n",x)
print()
print("This is  :\n",y)
# Out:
# This is x :
#      mileage  age
# 0     69000    6
# 1     35000    3
# 2     57000    5
# 3     22500    2
# 4     46000    4
# 5     59000    5
# 6     52000    5
# 7     72000    6
# 8     91000    8
# 9     67000    6
# 10    83000    7
# 11    79000    7
# 12    59000    5
#
# This is  :
#  0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: sell_price, dtype: int64

# %% [markdown]
# ###  Now we are ready to perform  train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test ,y_train ,y_test =train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train
# Out:
#     mileage  age
# 10    83000    7
# 1     35000    3
# 6     52000    5
# 0     69000    6
# 7     72000    6
# 12    59000    5
# 9     67000    6
# 8     91000    8
# 11    79000    7
# 5     59000    5

# %%
x_test
# Out:
#    mileage  age
# 2    57000    5
# 3    22500    2
# 4    46000    4

# %%
y_train
# Out:
# 10    20000
# 1     34000
# 6     32000
# 0     18000
# 7     19300
# 12    33000
# 9     22000
# 8     12000
# 11    21000
# 5     29400
# Name: sell_price, dtype: int64

# %%
y_test
# Out:
# 2    26100
# 3    40000
# 4    31500
# Name: sell_price, dtype: int64

# %%
print(len(x_test),len(y_test))
# Out:
# 3 3

# %%
print("x_train size :",len(x_train))
print("x_test size :",len(x_test))
print("y_train size :",len(y_train))
print("y_test size :",len(y_test))
# Out:
# x_train size : 10
# x_test size : 3
# y_train size : 10
# y_test size : 3

# %% [markdown]
# ###  so , now we will apply linear regression :

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
# we will train our model with training data( i.e x_train and x_train)
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_train,y_train)
# Out:
# 0.8786023894827195

# %%
# Now we will only give test data (i.e x_test)
predicted = reg.predict(x_test)
predicted
# Out:
# array([32066.93147964, 23070.87057266, 17402.25642723])

# %%
y_test
# Out:
# 4     31500
# 0     18000
# 10    20000
# Name: sell_price, dtype: int64

# %%
# lets cjeck our model accurascy 
reg.score(x_test,y_test)
# Out:
# 0.9015224345496103
