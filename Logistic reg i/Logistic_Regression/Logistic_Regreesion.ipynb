# %% [markdown]
# ![ML%20_graph.PNG](attachment:ML%20_graph.PNG)

# %% [markdown]
# ![Lin_vs_Log.PNG](attachment:Lin_vs_Log.PNG)

# %% [markdown]
# ![Log_Reg.PNG](attachment:Log_Reg.PNG)

# %% [markdown]
# #  ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬

# %% [markdown]
# # Logistic_Regression_single_variable (or Only one Independent Variable)

# %% [markdown]
# #  ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬

# %% [markdown]
# ![Class_data.PNG](attachment:Class_data.PNG)

# %% [markdown]
# ![Log_Reg.png](attachment:Log_Reg.png)

# %% [markdown]
# ![cap2.PNG](attachment:cap2.PNG)

# %% [markdown]
# ![cap3.PNG](attachment:cap3.PNG)

# %% [markdown]
# ![Sigmoid.PNG](attachment:Sigmoid.PNG)

# %% [markdown]
# ![sigmoid2.PNG](attachment:sigmoid2.PNG)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv("insurance_data.csv")
df.sample(4)
# Out:
#     age  bought_insurance
# 0    22                 0
# 19   18                 0
# 24   50                 1
# 5    56                 1

# %%
df.shape
# Out:
# (27, 2)

# %%
df.bought_insurance.unique()
# Out:
# array([0, 1])

# %%
df.age.unique()
# Out:
# array([22, 25, 47, 52, 46, 56, 55, 60, 62, 61, 18, 28, 27, 29, 49, 58, 19,
#        21, 26, 40, 45, 50, 54, 23])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               27 non-null     int64
#  1   bought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 560.0 bytes

# %%
df.isnull().sum()
# Out:
# age                 0
# bought_insurance    0
# dtype: int64

# %%
sn.heatmap(df.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                        age  bought_insurance
# age               1.000000          0.732395
# bought_insurance  0.732395          1.000000

# %%
#plt.figure(figsize=(10,10))
plt.scatter(df.age,df.bought_insurance,marker='+',c='r')
plt.xlabel("Age")
plt.ylabel("Bought_Insurance")
#plt.savefig("Log_Reg.png",bbox_inches='tight',pad_inches=2,transparent=True)
# Out:
# Text(0, 0.5, 'Bought_Insurance')

# %%
sn.jointplot(data=df, x="age", y="bought_insurance",kind='reg')

# %%
sn.countplot(x='bought_insurance',data =df)
# Out:
# <AxesSubplot:xlabel='bought_insurance', ylabel='count'>

# %%
sn.pairplot(df)

# %%
df.hist(bins = 40)
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'bought_insurance'}>]], dtype=object)

# %%
from sklearn.linear_model import LogisticRegression
#Logistic_regression_used_to_make_linear_classification

reg = LogisticRegression()
reg.fit(df[["age"]],df.bought_insurance)
# Out:
# LogisticRegression()

# %%
reg.predict([[34],[24],[56],[30],[31],[32],[33],[28],[78]])
# Out:
# array([0, 0, 1, 0, 0, 0, 0, 0, 1])

# %%
reg.coef_
# Out:
# array([[0.1354656]])

# %%
reg.intercept_
# Out:
# array([-5.26279696])

# %%
reg.score(df[["age"]],df.bought_insurance)
# Out:
# 0.8888888888888888

# %% [markdown]
# #  ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬

# %% [markdown]
# # MUTIVARIABLE_LOGISTIC_REGRESSION

# %% [markdown]
# #  ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬ ▬  ▬  ▬  ▬

# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"salaries.csv")
df1.head(5)
# Out:
#   company                  job     degree  salary_more_then_10lac
# 0  google      sales executive  bachelors                       0
# 1  google      sales executive    masters                       0
# 2  google     business manager  bachelors                       1
# 3  google     business manager    masters                       1
# 4  google  computer programmer  bachelors                       0

# %%
df1.shape
# Out:
# (16, 4)

# %% [markdown]
# ###  in this Dataset we have all Categorical Columns :

# %% [markdown]
# #### 1- company

# %%
df1.company.unique()
# Out:
# array(['google', 'abc pharma', 'facebook'], dtype=object)

# %% [markdown]
# ### 2-job

# %%
df1.job.unique()
# Out:
# array(['sales executive', 'business manager', 'computer programmer'],
#       dtype=object)

# %% [markdown]
# ### 3-degree

# %%
df1.degree.unique()
# Out:
# array(['bachelors', 'masters'], dtype=object)

# %% [markdown]
# ## 4- 'salary_more_then_10lac'  and this is our Target

# %%
df1.salary_more_then_10lac.unique()
# Out:
# array([0, 1])

# %%
df1.columns
# Out:
# Index(['company', 'job', 'degree', 'salary_more_then_10lac'], dtype='object')

# %%
for col in df1.columns:
    categories=df1[col].unique()
    l=len(categories)
    print(categories)
    print(l)
# Out:
# ['google' 'abc pharma' 'facebook']
# 3
# ['sales executive' 'business manager' 'computer programmer']
# 3
# ['bachelors' 'masters']
# 2
# [0 1]
# 2

# %%
#so Lets find unique values of each columns by a function :
def Unique_values(df):
    for col in df.columns:
        categories=df[col].unique()
        l=len(categories)
        print(f"'{col.title()}' contains  :'{l}'  categories :")
        print(categories)
        print()
        
Unique_values(df1)
# Out:
# 'Company' contains  :'3'  categories :
# ['google' 'abc pharma' 'facebook']
#
# 'Job' contains  :'3'  categories :
# ['sales executive' 'business manager' 'computer programmer']
#
# 'Degree' contains  :'2'  categories :
# ['bachelors' 'masters']
#
# 'Salary_More_Then_10Lac' contains  :'2'  categories :
# [0 1]

# %% [markdown]
# ##  1- Let do it by Dummies :

# %% [markdown]
# ## 2- Let do by it Label Encoder :
